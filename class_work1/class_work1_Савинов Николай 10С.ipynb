# %%
name = ['N', 'i','k','o','l','a','y', 16]
name[1:7:1]
# Out:
# ['i', 'k', 'o', 'l', 'a', 'y']

# %%
name = ['N', 'i','k','o','l','a','y', 16]
name.append('10C')
name
# Out:
# ['N', 'i', 'k', 'o', 'l', 'a', 'y', 16, '10C']

# %%
surname = list('Savinov')
name.append(surname)
print(name)
# Out:
# ['N', 'i', 'k', 'o', 'l', 'a', 'y', 16, '10C', ['S', 'a', 'v', 'i', 'n', 'o', 'v']]
